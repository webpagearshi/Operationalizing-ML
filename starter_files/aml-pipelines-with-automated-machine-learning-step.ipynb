# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code AYNH9TR3Q to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# quick-starts-ws-131353
# aml-quickstarts-131353
# southcentralus
# 3e42d11f-d64d-4173-af9b-12ecaa1030b3

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'udacity-project'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: udacity-project,
# Workspace: quick-starts-ws-131353)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "project-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://raw.githubusercontent.com/webpagearshi/Operationalizing-ML/master/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 4,
    "primary_metric" : 'accuracy'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [22cef667][35444b66-1986-4118-93a2-2603df7f23e0], (This step will run and generate new outputs)
# Submitted PipelineRun bc7e1c15-62cc-4f8f-b278-529ba928ee70
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/bc7e1c15-62cc-4f8f-b278-529ba928ee70?wsid=/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourcegroups/aml-quickstarts-131353/workspaces/quick-starts-ws-131353

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-c18ecff4a1a2> in <module>
# ----> 1 from azureml.widgets import RunDetails
#       2 RunDetails(pipeline_run).show()
#
# ModuleNotFoundError: No module named 'azureml.widgets'

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: bc7e1c15-62cc-4f8f-b278-529ba928ee70
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/bc7e1c15-62cc-4f8f-b278-529ba928ee70?wsid=/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourcegroups/aml-quickstarts-131353/workspaces/quick-starts-ws-131353
# PipelineRun Status: Running
#
#
# StepRunId: 8a4f8053-019e-4c93-98f4-d43b6514471a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/8a4f8053-019e-4c93-98f4-d43b6514471a?wsid=/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourcegroups/aml-quickstarts-131353/workspaces/quick-starts-ws-131353
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '8a4f8053-019e-4c93-98f4-d43b6514471a', 'target': 'project-compute', 'status': 'Completed', 'startTimeUtc': '2020-12-22T14:09:38.264969Z', 'endTimeUtc': '2020-12-22T14:39:44.072477Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4e741016-fff3-4e98-be00-634d7c0793c5', 'StepType': 'AutoMLStep', 'azureml.moduleid': '35444b66-1986-4118-93a2-2603df7f23e0', 'azureml.nodeid': '22cef667', 'azureml.pipelinerunid': 'bc7e1c15-62cc-4f8f-b278-529ba928ee70', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'accuracy', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'project-compute', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "3e42d11f-d64d-4173-af9b-12ecaa1030b3", "resource_group": "aml-quickstarts-131353", "workspace_name": "quick-starts-ws-131353", "region": "southcentralus", "compute_target": "project-compute", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "accuracy", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 4, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["LinearSVM", "ExtremeRandomTrees", "MultinomialNaiveBayes", "BernoulliNaiveBayes", "XGBoostClassifier", "SGD", "TensorFlowDNN", "DecisionTree", "LightGBM", "TensorFlowLinearClassifier", "SVM", "KNN", "RandomForest", "AveragedPerceptronClassifier", "GradientBoosting", "LogisticRegression"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"1a82004c-6fce-454f-b683-9b8f9cfb6a7e\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '4e741016-fff3-4e98-be00-634d7c0793c5', 'SetupRunId': '8a4f8053-019e-4c93-98f4-d43b6514471a_setup', 'SetupRunContainerId': 'dcid.8a4f8053-019e-4c93-98f4-d43b6514471a_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '8a4f8053-019e-4c93-98f4-d43b6514471a_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'bc7e1c15-62cc-4f8f-b278-529ba928ee70', 'status': 'Completed', 'startTimeUtc': '2020-12-22T14:09:09.551073Z', 'endTimeUtc': '2020-12-22T14:40:58.710663Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg131353.blob.core.windows.net/azureml/ExperimentRun/dcid.bc7e1c15-62cc-4f8f-b278-529ba928ee70/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=OGcjjYw2x96bp63xVxR4%2FLM%2F4yWy3x8Fk4CDPCIQcgA%3D&st=2020-12-22T13%3A59%3A35Z&se=2020-12-22T22%3A09%3A35Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg131353.blob.core.windows.net/azureml/ExperimentRun/dcid.bc7e1c15-62cc-4f8f-b278-529ba928ee70/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Q%2BbK566Tze6gKWG34NqZqBh6QqfxEI4HzJzNyjpcUv4%3D&st=2020-12-22T13%3A59%3A35Z&se=2020-12-22T22%3A09%3A35Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg131353.blob.core.windows.net/azureml/ExperimentRun/dcid.bc7e1c15-62cc-4f8f-b278-529ba928ee70/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=WF44BrneDGXLS0UlvCUc9VoxXHsaY5AEJVi45nKBXm8%3D&st=2020-12-22T13%3A59%3A35Z&se=2020-12-22T22%3A09%3A35Z&sp=r'}}
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fcefd1f0b00>: Failed to establish a new connection: [Errno 111] Connection refused',)': /pipelines/v1.0/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourceGroups/aml-quickstarts-131353/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-131353/PipelineRuns/bc7e1c15-62cc-4f8f-b278-529ba928ee70/Graph/Node/StatusCode
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/8a4f8053-019e-4c93-98f4-d43b6514471a/metrics_data
# Downloaded azureml/8a4f8053-019e-4c93-98f4-d43b6514471a/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_28  \
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.8556646605427094]
# precision_score_micro                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_macro                       [0.7070313284526243]
# f1_score_macro                                      [0.4703423886834914]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.9594264821911673]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9587514074988314]
# average_precision_score_weighted                    [0.9176992281894447]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# log_loss                                            [0.2706539249576787]
# AUC_weighted                                        [0.8556646605427093]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_30  \
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                                          [0.5]
# precision_score_micro                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_macro                                      [0.5]
# f1_score_macro                                      [0.4703423886834914]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.8445594902839405]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.8880121396054628]
# average_precision_score_weighted                    [0.8011068409624182]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# log_loss                                           [0.35067519027071736]
# AUC_weighted                                                       [0.5]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_36  \
# precision_score_macro                                [0.795498259851013]
# AUC_macro                                           [0.9432626281150029]
# precision_score_micro                               [0.9162367223065251]
# recall_score_micro                                  [0.9162367223065251]
# matthews_correlation                                [0.5541743038322214]
# precision_score_weighted                            [0.9116925573665358]
# accuracy                                            [0.9162367223065251]
# f1_score_micro                                      [0.9162367223065252]
# average_precision_score_macro                       [0.8171605392847131]
# f1_score_macro                                      [0.7760367002119897]
# f1_score_weighted                                   [0.9135478074217047]
# average_precision_score_micro                       [0.9802805491181896]
# weighted_accuracy                                   [0.9550699805016006]
# AUC_micro                                           [0.9793416704852388]
# average_precision_score_weighted                    [0.9533820958615844]
# recall_score_macro                                  [0.7598231535972229]
# balanced_accuracy                                   [0.7598231535972229]
# log_loss                                           [0.20298782300757992]
# AUC_weighted                                        [0.9432626281150029]
# recall_score_weighted                               [0.9162367223065251]
# norm_macro_recall                                   [0.5196463071944457]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_10  \
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.9071477659410907]
# precision_score_micro                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_macro                       [0.7391460782932224]
# f1_score_macro                                      [0.4703423886834914]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.9704592271137742]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9689910449685802]
# average_precision_score_weighted                    [0.9319918995434631]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# log_loss                                            [0.2548841954479783]
# AUC_weighted                                        [0.9071477659410909]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_25  \
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                                          [0.5]
# precision_score_micro                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_macro                                      [0.5]
# f1_score_macro                                      [0.4703423886834914]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.8445594902839405]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.8880121396054628]
# average_precision_score_weighted                    [0.8011068409624182]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# log_loss                                           [0.35065167860756286]
# AUC_weighted                                                       [0.5]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_24  \
# precision_score_macro                               [0.8115592342846185]
# AUC_macro                                           [0.8573957065613034]
# precision_score_micro                               [0.8959028831562974]
# recall_score_micro                                  [0.8959028831562974]
# matthews_correlation                               [0.25983977169934064]
# precision_score_weighted                             [0.879400288126985]
# accuracy                                            [0.8959028831562974]
# f1_score_micro                                      [0.8959028831562974]
# average_precision_score_macro                       [0.7185955274087281]
# f1_score_macro                                       [0.570533298930955]
# f1_score_weighted                                   [0.8606204770565479]
# average_precision_score_micro                       [0.9599652648449915]
# weighted_accuracy                                   [0.9807443102074737]
# AUC_micro                                            [0.959326150579924]
# average_precision_score_weighted                    [0.9204106849827809]
# recall_score_macro                                  [0.5541764611084252]
# balanced_accuracy                                   [0.5541764611084252]
# log_loss                                           [0.27014666553229766]
# AUC_weighted                                        [0.8573957065613035]
# recall_score_weighted                               [0.8959028831562974]
# norm_macro_recall                                  [0.10835292221685044]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_0  \
# precision_score_macro                              [0.7819118765348991]
# AUC_macro                                          [0.9450464668693166]
# precision_score_micro                              [0.9116843702579667]
# recall_score_micro                                 [0.9116843702579667]
# matthews_correlation                               [0.5323740218566827]
# precision_score_weighted                           [0.9072720074188747]
# accuracy                                           [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# average_precision_score_macro                      [0.8151093723721079]
# f1_score_macro                                     [0.7653697272147331]
# f1_score_weighted                                  [0.9091539479147899]
# average_precision_score_micro                      [0.9806603102489483]
# weighted_accuracy                                  [0.9514937218005303]
# AUC_micro                                           [0.979695082216353]
# average_precision_score_weighted                   [0.9531771295804466]
# recall_score_macro                                 [0.7513392683482543]
# balanced_accuracy                                  [0.7513392683482543]
# log_loss                                          [0.17775706110025447]
# AUC_weighted                                       [0.9450464668693167]
# recall_score_weighted                              [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_17  \
# precision_score_macro                               [0.7843493271725731]
# AUC_macro                                           [0.9413139278351088]
# precision_score_micro                               [0.9119878603945372]
# recall_score_micro                                  [0.9119878603945372]
# matthews_correlation                                [0.5272437746365841]
# precision_score_weighted                            [0.9064487396112422]
# accuracy                                            [0.9119878603945372]
# f1_score_micro                                      [0.9119878603945372]
# average_precision_score_macro                         [0.81452154874972]
# f1_score_macro                                      [0.7622300189111176]
# f1_score_weighted                                    [0.908666271558576]
# average_precision_score_micro                       [0.9798454227590244]
# weighted_accuracy                                   [0.9535940623872897]
# AUC_micro                                           [0.9788715601189093]
# average_precision_score_weighted                     [0.952602066668614]
# recall_score_macro                                   [0.744405359296245]
# balanced_accuracy                                    [0.744405359296245]
# log_loss                                           [0.20853708938378565]
# AUC_weighted                                        [0.9413139278351087]
# recall_score_weighted                               [0.9119878603945372]
# norm_macro_recall                                   [0.4888107185924899]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_18  \
# precision_score_macro                               [0.7653000170128346]
# AUC_macro                                           [0.9207960774071171]
# precision_score_micro                               [0.9025796661608497]
# recall_score_micro                                  [0.9025796661608497]
# matthews_correlation                               [0.42527474546043575]
# precision_score_weighted                            [0.8887696135205639]
# accuracy                                            [0.9025796661608497]
# f1_score_micro                                      [0.9025796661608497]
# average_precision_score_macro                       [0.7622441012887955]
# f1_score_macro                                      [0.7034797905817874]
# f1_score_weighted                                   [0.8920347468246255]
# average_precision_score_micro                       [0.9675290500741985]
# weighted_accuracy                                   [0.9602165507712037]
# AUC_micro                                           [0.9697033948065885]
# average_precision_score_weighted                    [0.9382493224026208]
# recall_score_macro                                  [0.6704283806337722]
# balanced_accuracy                                   [0.6704283806337722]
# log_loss                                           [0.22595593251490004]
# AUC_weighted                                         [0.920796077407117]
# recall_score_weighted                               [0.9025796661608497]
# norm_macro_recall                                   [0.3408567612675444]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_16  ...  \
# precision_score_macro                               [0.7766876160331132]  ...
# AUC_macro                                           [0.9398625906969937]  ...
# precision_score_micro                               [0.9092564491654022]  ...
# recall_score_micro                                  [0.9092564491654022]  ...
# matthews_correlation                                [0.5108134720391224]  ...
# precision_score_weighted                            [0.9032193466487394]  ...
# accuracy                                            [0.9092564491654022]  ...
# f1_score_micro                                       [0.909256449165402]  ...
# average_precision_score_macro                       [0.8070851787197519]  ...
# f1_score_macro                                      [0.7538895471285886]  ...
# f1_score_weighted                                   [0.9056363647405566]  ...
# average_precision_score_micro                       [0.9790657149331647]  ...
# weighted_accuracy                                   [0.9523302708540262]  ...
# AUC_micro                                           [0.9780349589321199]  ...
# average_precision_score_weighted                    [0.9507908072365806]  ...
# recall_score_macro                                  [0.7357626327459447]  ...
# balanced_accuracy                                   [0.7357626327459447]  ...
# log_loss                                            [0.1896958450479275]  ...
# AUC_weighted                                        [0.9398625906969938]  ...
# recall_score_weighted                               [0.9092564491654022]  ...
# norm_macro_recall                                  [0.47152526549188933]  ...
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_22  \
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.8856842772118767]
# precision_score_micro                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_macro                       [0.7231872291362442]
# f1_score_macro                                      [0.4703423886834914]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.9661143893902722]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9647221038912592]
# average_precision_score_weighted                    [0.9257572457572059]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# log_loss                                            [0.2871517004740542]
# AUC_weighted                                        [0.8856842772118767]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_21  \
# precision_score_macro                               [0.7649726288332503]
# AUC_macro                                           [0.9216055660214839]
# precision_score_micro                               [0.9025796661608497]
# recall_score_micro                                  [0.9025796661608497]
# matthews_correlation                               [0.42648619466677545]
# precision_score_weighted                            [0.8889110559014688]
# accuracy                                            [0.9025796661608497]
# f1_score_micro                                      [0.9025796661608497]
# average_precision_score_macro                       [0.7629922333224017]
# f1_score_macro                                      [0.7043745341088892]
# f1_score_weighted                                   [0.8922212808312255]
# average_precision_score_micro                       [0.9677706613496116]
# weighted_accuracy                                    [0.959922562875411]
# AUC_micro                                           [0.9699156076365303]
# average_precision_score_weighted                    [0.9385041279410853]
# recall_score_macro                                  [0.6716125124340785]
# balanced_accuracy                                   [0.6716125124340785]
# log_loss                                           [0.22533659863208075]
# AUC_weighted                                        [0.9216055660214839]
# recall_score_weighted                               [0.9025796661608497]
# norm_macro_recall                                    [0.343225024868157]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_29  \
# precision_score_macro                               [0.7946974049883324]
# AUC_macro                                           [0.8976589663367585]
# precision_score_micro                               [0.8998482549317147]
# recall_score_micro                                  [0.8998482549317147]
# matthews_correlation                                [0.3312889943073923]
# precision_score_weighted                            [0.8819647608160599]
# accuracy                                            [0.8998482549317147]
# f1_score_micro                                      [0.8998482549317147]
# average_precision_score_macro                       [0.7456523141608429]
# f1_score_macro                                      [0.6263741021433107]
# f1_score_weighted                                   [0.8744313595679113]
# average_precision_score_micro                       [0.9688666895069831]
# weighted_accuracy                                   [0.9760040571939254]
# AUC_micro                                           [0.9674688047600517]
# average_precision_score_weighted                     [0.932252424866035]
# recall_score_macro                                  [0.5931060096657016]
# balanced_accuracy                                   [0.5931060096657016]
# log_loss                                            [0.2506220054147641]
# AUC_weighted                                        [0.8976589663367585]
# recall_score_weighted                               [0.8998482549317147]
# norm_macro_recall                                   [0.1862120193314032]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_31  \
# precision_score_macro                               [0.7908196055445871]
# AUC_macro                                           [0.9406868983248957]
# precision_score_micro                               [0.9110773899848255]
# recall_score_micro                                  [0.9110773899848255]
# matthews_correlation                                [0.4937290323447371]
# precision_score_weighted                             [0.901311576372359]
# accuracy                                            [0.9110773899848255]
# f1_score_micro                                      [0.9110773899848255]
# average_precision_score_macro                       [0.8022857542994071]
# f1_score_macro                                      [0.7410400670578374]
# f1_score_weighted                                   [0.9038810538459678]
# average_precision_score_micro                       [0.9792469103727843]
# weighted_accuracy                                   [0.9611104717292754]
# AUC_micro                                           [0.9781896974539526]
# average_precision_score_weighted                    [0.9498586901696163]
# recall_score_macro                                  [0.7095528918378726]
# balanced_accuracy                                   [0.7095528918378726]
# log_loss                                           [0.18485719214536023]
# AUC_weighted                                        [0.9406868983248957]
# recall_score_weighted                               [0.9110773899848255]
# norm_macro_recall                                  [0.41910578367574525]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_37  \
# precision_score_macro                               [0.7928340577425737]
# AUC_macro                                           [0.9429004884717336]
# precision_score_micro                               [0.9122913505311078]
# recall_score_micro                                  [0.9122913505311078]
# matthews_correlation                                 [0.505931467506268]
# precision_score_weighted                             [0.903385015998195]
# accuracy                                            [0.9122913505311078]
# f1_score_micro                                      [0.9122913505311078]
# average_precision_score_macro                       [0.8185017744405645]
# f1_score_macro                                      [0.7481756216241231]
# f1_score_weighted                                   [0.9059364933591455]
# average_precision_score_micro                       [0.9802369747211654]
# weighted_accuracy                                   [0.9603982093067349]
# AUC_micro                                           [0.9793316309025724]
# average_precision_score_weighted                    [0.9536024325310396]
# recall_score_macro                                  [0.7185253414393338]
# balanced_accuracy                                   [0.7185253414393338]
# log_loss                                           [0.19867249298299816]
# AUC_weighted                                        [0.9429004884717336]
# recall_score_weighted                               [0.9122913505311078]
# norm_macro_recall                                  [0.43705068287866755]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_1  \
# precision_score_macro                              [0.7723958081530135]
# AUC_macro                                          [0.9392346349984347]
# precision_score_micro                              [0.9071320182094081]
# recall_score_micro                                 [0.9071320182094081]
# matthews_correlation                                [0.488678780261868]
# precision_score_weighted                           [0.8991976076061607]
# accuracy                                           [0.9071320182094081]
# f1_score_micro                                     [0.9071320182094081]
# average_precision_score_macro                      [0.8065229883244922]
# f1_score_macro                                     [0.7416848907681176]
# f1_score_weighted                                  [0.9021127651963996]
# average_precision_score_micro                      [0.9791945367231853]
# weighted_accuracy                                  [0.9537972210153172]
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_weighted                   [0.9505970434373063]
# recall_score_macro                                 [0.7191727470931578]
# balanced_accuracy                                  [0.7191727470931578]
# log_loss                                           [0.1874363495858499]
# AUC_weighted                                       [0.9392346349984347]
# recall_score_weighted                              [0.9071320182094081]
# norm_macro_recall                                 [0.43834549418631563]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_3  \
# precision_score_macro                              [0.4440060698027314]
# AUC_macro                                          [0.8946687672618353]
# precision_score_micro                              [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# matthews_correlation                                              [0.0]
# precision_score_weighted                            [0.788565560086672]
# accuracy                                           [0.8880121396054628]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_macro                      [0.7167735917669655]
# f1_score_macro                                     [0.4703423886834914]
# f1_score_weighted                                  [0.8353395018439429]
# average_precision_score_micro                      [0.9671418099541281]
# weighted_accuracy                                  [0.9843450583187134]
# AUC_micro                                          [0.9665090574996374]
# average_precision_score_weighted                   [0.9246564382408718]
# recall_score_macro                                                [0.5]
# balanced_accuracy                                                 [0.5]
# log_loss                                           [0.2564216385011348]
# AUC_weighted                                       [0.8946687672618353]
# recall_score_weighted                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_5  \
# precision_score_macro                               [0.666591033872287]
# AUC_macro                                          [0.8775736458663288]
# precision_score_micro                              [0.8245827010622154]
# recall_score_micro                                 [0.8245827010622154]
# matthews_correlation                              [0.44930311418069413]
# precision_score_weighted                           [0.8997039553983385]
# accuracy                                           [0.8245827010622154]
# f1_score_micro                                     [0.8245827010622154]
# average_precision_score_macro                      [0.7295266634597118]
# f1_score_macro                                     [0.6955706521739131]
# f1_score_weighted                                  [0.8493626377251435]
# average_precision_score_micro                      [0.8311764648846618]
# weighted_accuracy                                  [0.8299541588134801]
# AUC_micro                                          [0.8674570612115198]
# average_precision_score_weighted                    [0.925409812181168]
# recall_score_macro                                 [0.8029474091733398]
# balanced_accuracy                                  [0.8029474091733398]
# log_loss                                           [0.5303159620427209]
# AUC_weighted                                       [0.8775736458663289]
# recall_score_weighted                              [0.8245827010622154]
# norm_macro_recall                                  [0.6058948183466797]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_20  \
# precision_score_macro                               [0.7778399048408848]
# AUC_macro                                           [0.9226146482244043]
# precision_score_micro                               [0.9062215477996965]
# recall_score_micro                                  [0.9062215477996965]
# matthews_correlation                               [0.45259928835107144]
# precision_score_weighted                            [0.8939601245245358]
# accuracy                                            [0.9062215477996965]
# f1_score_micro                                      [0.9062215477996965]
# average_precision_score_macro                       [0.7826202808274194]
# f1_score_macro                                      [0.7179751817162724]
# f1_score_weighted                                   [0.8967812582672811]
# average_precision_score_micro                       [0.9749615376879663]
# weighted_accuracy                                   [0.9613136303573029]
# AUC_micro                                           [0.9738451371347124]
# average_precision_score_weighted                    [0.9433571046966222]
# recall_score_macro                                  [0.6843202796347854]
# balanced_accuracy                                   [0.6843202796347854]
# log_loss                                            [0.2084843943994691]
# AUC_weighted                                        [0.9226146482244043]
# recall_score_weighted                               [0.9062215477996965]
# norm_macro_recall                                  [0.36864055926957073]
#
#                                  8a4f8053-019e-4c93-98f4-d43b6514471a_26
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.9169181268025941]
# precision_score_micro                               [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_macro                        [0.757654218728435]
# f1_score_macro                                      [0.4703423886834914]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_micro                       [0.9723740370895435]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                            [0.970934302905262]
# average_precision_score_weighted                    [0.9372483415540177]
# recall_score_macro                                                 [0.5]
# balanced_accuracy                                                  [0.5]
# log_loss                                           [0.23164520616027615]
# AUC_weighted                                        [0.9169181268025941]
# recall_score_weighted                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
#
# [21 rows x 35 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/8a4f8053-019e-4c93-98f4-d43b6514471a/model_data
# Downloaded azureml/8a4f8053-019e-4c93-98f4-d43b6514471a/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                      n_jobs=1,
#                                                                                                                                      oob_score=False,
#                                                                                                                                      random_state=None,
#                                                                                                                                      verbose=0,
#                                                                                                                                      warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.15384615384615385,
#                                                                                          0.15384615384615385,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693,
#                                                                                          0.3076923076923077,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693,
#                                                                                          0.07692307692307693]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('17',
#                                              Pipeline(memory=None,
#                                                       steps=[('sparsenormalizer',
#                                                               <azureml.automl.runtime.shared.model_wrappers.SparseNormalizer object at 0x7fce51696f60>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 eta=0.3,
#                                                                                 gam...
#                                                                                      min_samples_split=0.2442105263157895,
#                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                      n_estimators=10,
#                                                                                      n_jobs=1,
#                                                                                      oob_score=False,
#                                                                                      random_state=None,
#                                                                                      verbose=0,
#                                                                                      warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.15384615384615385, 0.15384615384615385,
#                                          0.07692307692307693, 0.07692307692307693,
#                                          0.3076923076923077, 0.07692307692307693,
#                                          0.07692307692307693,
#                                          0.07692307692307693]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://raw.githubusercontent.com/webpagearshi/Operationalizing-ML/master/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_83a58066_4464_11eb_bfe6_000d3aeb0307row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_83a58066_4464_11eb_bfe6_000d3aeb0307row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_83a58066_4464_11eb_bfe6_000d3aeb0307row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_83a58066_4464_11eb_bfe6_000d3aeb0307row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_83a58066_4464_11eb_bfe6_000d3aeb0307" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a58066_4464_11eb_bfe6_000d3aeb0307level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_83a58066_4464_11eb_bfe6_000d3aeb0307row0_col0" class="data row0 col0" >28683</td>
#                         <td id="T_83a58066_4464_11eb_bfe6_000d3aeb0307row0_col1" class="data row0 col1" >575</td>
#             </tr>
#             <tr>
#                         <th id="T_83a58066_4464_11eb_bfe6_000d3aeb0307level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_83a58066_4464_11eb_bfe6_000d3aeb0307row1_col0" class="data row1 col0" >1055</td>
#                         <td id="T_83a58066_4464_11eb_bfe6_000d3aeb0307row1_col1" class="data row1 col1" >2637</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: f3b7cc74-5ccb-4e84-b3b6-a000c2b00600,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourceGroups/aml-quickstarts-131353/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-131353/PipelineRuns/PipelineSubmit/f3b7cc74-5ccb-4e84-b3b6-a000c2b00600)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  a2a40eff-4708-42be-9718-53078b03baae

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
#from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
#RunDetails(published_pipeline_run).show()
