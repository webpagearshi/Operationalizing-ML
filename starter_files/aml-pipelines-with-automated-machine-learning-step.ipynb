# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code F5QZMY3UR to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# quick-starts-ws-130975
# aml-quickstarts-130975
# southcentralus
# 1b944a9b-fdae-4f97-aeb1-b7eea0beac53

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'udacity-project'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: udacity-project,
# Workspace: quick-starts-ws-130975)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "project-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://raw.githubusercontent.com/webpagearshi/Operationalizing-ML/master/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 4,
    "primary_metric" : 'accuracy'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [c212fb7b][34bd3fa6-0551-463a-8088-127e4cd8d9fa], (This step will run and generate new outputs)
# Submitted PipelineRun 357c562d-e3c6-4bb0-9009-98a18dc10ff5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/357c562d-e3c6-4bb0-9009-98a18dc10ff5?wsid=/subscriptions/1b944a9b-fdae-4f97-aeb1-b7eea0beac53/resourcegroups/aml-quickstarts-130975/workspaces/quick-starts-ws-130975

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-c18ecff4a1a2> in <module>
# ----> 1 from azureml.widgets import RunDetails
#       2 RunDetails(pipeline_run).show()
#
# ModuleNotFoundError: No module named 'azureml.widgets'

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 357c562d-e3c6-4bb0-9009-98a18dc10ff5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/357c562d-e3c6-4bb0-9009-98a18dc10ff5?wsid=/subscriptions/1b944a9b-fdae-4f97-aeb1-b7eea0beac53/resourcegroups/aml-quickstarts-130975/workspaces/quick-starts-ws-130975
# PipelineRun Status: Running
#
#
# StepRunId: 8b93428b-bdf7-4daa-8044-5ebd72e5a6ad
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/udacity-project/runs/8b93428b-bdf7-4daa-8044-5ebd72e5a6ad?wsid=/subscriptions/1b944a9b-fdae-4f97-aeb1-b7eea0beac53/resourcegroups/aml-quickstarts-130975/workspaces/quick-starts-ws-130975
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '8b93428b-bdf7-4daa-8044-5ebd72e5a6ad', 'target': 'project-compute', 'status': 'Completed', 'startTimeUtc': '2020-12-19T10:59:43.330596Z', 'endTimeUtc': '2020-12-19T11:27:44.710308Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '5ebb4fd5-66ff-4beb-96dc-f15f77ef953e', 'StepType': 'AutoMLStep', 'azureml.moduleid': '34bd3fa6-0551-463a-8088-127e4cd8d9fa', 'azureml.nodeid': 'c212fb7b', 'azureml.pipelinerunid': '357c562d-e3c6-4bb0-9009-98a18dc10ff5', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'accuracy', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'project-compute', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "1b944a9b-fdae-4f97-aeb1-b7eea0beac53", "resource_group": "aml-quickstarts-130975", "workspace_name": "quick-starts-ws-130975", "region": "southcentralus", "compute_target": "project-compute", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "accuracy", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 4, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["BernoulliNaiveBayes", "SVM", "XGBoostClassifier", "AveragedPerceptronClassifier", "KNN", "LogisticRegression", "TensorFlowDNN", "TensorFlowLinearClassifier", "LinearSVM", "MultinomialNaiveBayes", "DecisionTree", "ExtremeRandomTrees", "LightGBM", "GradientBoosting", "RandomForest", "SGD"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"f1eda147-0eb0-43b8-aacf-153c550fa60a\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '5ebb4fd5-66ff-4beb-96dc-f15f77ef953e', 'SetupRunId': '8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_setup', 'SetupRunContainerId': 'dcid.8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '357c562d-e3c6-4bb0-9009-98a18dc10ff5', 'status': 'Completed', 'startTimeUtc': '2020-12-19T10:59:13.808849Z', 'endTimeUtc': '2020-12-19T11:29:11.091079Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg130975.blob.core.windows.net/azureml/ExperimentRun/dcid.357c562d-e3c6-4bb0-9009-98a18dc10ff5/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=AybHEX%2FQrQKfG8WOrkisOGs0QMdqmd9F4wwGrCSVJmI%3D&st=2020-12-19T10%3A49%3A32Z&se=2020-12-19T18%3A59%3A32Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg130975.blob.core.windows.net/azureml/ExperimentRun/dcid.357c562d-e3c6-4bb0-9009-98a18dc10ff5/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=qCqfXnbBEi5nxHK539i1ZGPCBGNke0F5ZKblDIq89UE%3D&st=2020-12-19T10%3A49%3A32Z&se=2020-12-19T18%3A59%3A32Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg130975.blob.core.windows.net/azureml/ExperimentRun/dcid.357c562d-e3c6-4bb0-9009-98a18dc10ff5/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=2F6T3z42OSkIvWRY%2FaddNDV0MGNrkOlkgq87whruoOc%3D&st=2020-12-19T10%3A49%3A32Z&se=2020-12-19T18%3A59%3A32Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/8b93428b-bdf7-4daa-8044-5ebd72e5a6ad/metrics_data
# Downloaded azureml/8b93428b-bdf7-4daa-8044-5ebd72e5a6ad/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_3  \
# average_precision_score_micro                      [0.9655931032206119]
# AUC_weighted                                       [0.8902814130670356]
# matthews_correlation                                              [0.0]
# precision_score_micro                              [0.8880121396054628]
# f1_score_micro                                     [0.8880121396054628]
# log_loss                                           [0.2667331652532011]
# weighted_accuracy                                  [0.9843450583187134]
# recall_score_micro                                 [0.8880121396054628]
# average_precision_score_macro                      [0.7145183611028729]
# f1_score_macro                                     [0.4703423886834914]
# precision_score_weighted                            [0.788565560086672]
# balanced_accuracy                                                 [0.5]
# average_precision_score_weighted                   [0.9230392210367201]
# AUC_macro                                          [0.8902814130670356]
# AUC_micro                                           [0.965636442764017]
# precision_score_macro                              [0.4440060698027314]
# recall_score_macro                                                [0.5]
# f1_score_weighted                                  [0.8353395018439429]
# norm_macro_recall                                                 [0.0]
# recall_score_weighted                              [0.8880121396054628]
# accuracy                                           [0.8880121396054628]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_2  \
# average_precision_score_micro                      [0.9691386858934591]
# AUC_weighted                                        [0.902958152958153]
# matthews_correlation                             [0.049063912865329386]
# precision_score_micro                              [0.8883156297420334]
# f1_score_micro                                     [0.8883156297420334]
# log_loss                                          [0.24176279996799183]
# weighted_accuracy                                  [0.9843874836349229]
# recall_score_micro                                 [0.8883156297420334]
# average_precision_score_macro                      [0.7516855008670387]
# f1_score_macro                                    [0.47312070913357085]
# precision_score_weighted                           [0.9007928150046113]
# balanced_accuracy                                  [0.5013550135501355]
# average_precision_score_weighted                   [0.9338006294965624]
# AUC_macro                                           [0.902958152958153]
# AUC_micro                                          [0.9681596938387819]
# precision_score_macro                              [0.9441408621736491]
# recall_score_macro                                 [0.5013550135501355]
# f1_score_weighted                                  [0.8360791405851395]
# norm_macro_recall                               [0.0027100271002709064]
# recall_score_weighted                              [0.8883156297420334]
# accuracy                                           [0.8883156297420334]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_18  \
# average_precision_score_micro                        [0.973913451680861]
# AUC_weighted                                        [0.9197184572665958]
# matthews_correlation                               [0.44345496632973186]
# precision_score_micro                               [0.9034901365705614]
# f1_score_micro                                      [0.9034901365705614]
# log_loss                                            [0.2124912708516916]
# weighted_accuracy                                   [0.9576979356576965]
# recall_score_micro                                  [0.9034901365705614]
# average_precision_score_macro                       [0.7607732672800063]
# f1_score_macro                                      [0.7152677837729731]
# precision_score_weighted                            [0.8914722051528438]
# balanced_accuracy                                   [0.6851506074869361]
# average_precision_score_weighted                     [0.938249761397204]
# AUC_macro                                            [0.919718457266596]
# AUC_micro                                            [0.972612847442094]
# precision_score_macro                               [0.7655301943532362]
# recall_score_macro                                  [0.6851506074869361]
# f1_score_weighted                                   [0.8949186072531649]
# norm_macro_recall                                  [0.37030121497387225]
# recall_score_weighted                               [0.9034901365705614]
# accuracy                                            [0.9034901365705614]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_22  \
# average_precision_score_micro                       [0.9768347564679163]
# AUC_weighted                                        [0.9297583389367728]
# matthews_correlation                               [0.41777121332502914]
# precision_score_micro                               [0.9068285280728376]
# f1_score_micro                                      [0.9068285280728376]
# log_loss                                           [0.20745797542673844]
# weighted_accuracy                                   [0.9722760331340571]
# recall_score_micro                                  [0.9068285280728376]
# average_precision_score_macro                        [0.796541472860828]
# f1_score_macro                                      [0.6855885736273785]
# precision_score_weighted                            [0.8925922069110227]
# balanced_accuracy                                   [0.6432174301237202]
# average_precision_score_weighted                    [0.9473070209964983]
# AUC_macro                                           [0.9297583389367727]
# AUC_micro                                           [0.9757207890743551]
# precision_score_macro                               [0.8046640107497645]
# recall_score_macro                                  [0.6432174301237202]
# f1_score_weighted                                   [0.8902595445090857]
# norm_macro_recall                                  [0.28643486024744047]
# recall_score_weighted                               [0.9068285280728376]
# accuracy                                            [0.9068285280728376]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_21  \
# average_precision_score_micro                       [0.9765734087501672]
# AUC_weighted                                        [0.9299292206866019]
# matthews_correlation                               [0.39407592882164066]
# precision_score_micro                               [0.9047040971168437]
# f1_score_micro                                      [0.9047040971168437]
# log_loss                                           [0.23379019594783554]
# weighted_accuracy                                   [0.9731550075037622]
# recall_score_micro                                  [0.9047040971168437]
# average_precision_score_macro                       [0.7949463497788075]
# f1_score_macro                                       [0.669888557914915]
# precision_score_weighted                            [0.8893566710320148]
# balanced_accuracy                                   [0.6289958080715462]
# average_precision_score_weighted                     [0.946911942171678]
# AUC_macro                                           [0.9299292206866019]
# AUC_micro                                            [0.975556471501171]
# precision_score_macro                               [0.8009707059443854]
# recall_score_macro                                  [0.6289958080715462]
# f1_score_weighted                                   [0.8859458928337101]
# norm_macro_recall                                   [0.2579916161430924]
# recall_score_weighted                               [0.9047040971168437]
# accuracy                                            [0.9047040971168437]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_36  \
# average_precision_score_micro                       [0.9804348019954829]
# AUC_weighted                                        [0.9435840154710501]
# matthews_correlation                                [0.5543479395284133]
# precision_score_micro                               [0.9165402124430956]
# f1_score_micro                                      [0.9165402124430956]
# log_loss                                           [0.20396794609240795]
# weighted_accuracy                                   [0.9557003816093957]
# recall_score_micro                                  [0.9165402124430956]
# average_precision_score_macro                       [0.8177874952899078]
# f1_score_macro                                      [0.7759847215955795]
# precision_score_weighted                               [0.9117756203427]
# balanced_accuracy                                   [0.7588099035467457]
# average_precision_score_weighted                    [0.9535709750275007]
# AUC_macro                                           [0.9435840154710501]
# AUC_micro                                           [0.9794933695003926]
# precision_score_macro                               [0.7968410731661717]
# recall_score_macro                                  [0.7588099035467457]
# f1_score_weighted                                   [0.9136860204833568]
# norm_macro_recall                                   [0.5176198070934914]
# recall_score_weighted                               [0.9165402124430956]
# accuracy                                            [0.9165402124430956]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_11  \
# average_precision_score_micro                       [0.9720372777845872]
# AUC_weighted                                        [0.9137232401032145]
# matthews_correlation                                [0.3233384145676746]
# precision_score_micro                               [0.9010622154779969]
# f1_score_micro                                      [0.9010622154779969]
# log_loss                                           [0.22160536057926264]
# weighted_accuracy                                   [0.9829354800619984]
# recall_score_micro                                  [0.9010622154779969]
# average_precision_score_macro                       [0.7678853944295394]
# f1_score_macro                                      [0.5979457305150571]
# precision_score_weighted                             [0.894446405152466]
# balanced_accuracy                                   [0.5712910324591968]
# average_precision_score_weighted                    [0.9391975851150038]
# AUC_macro                                           [0.9137232401032145]
# AUC_micro                                           [0.9706205889734989]
# precision_score_macro                               [0.8666230054774946]
# recall_score_macro                                  [0.5712910324591968]
# f1_score_weighted                                   [0.8688541024305542]
# norm_macro_recall                                  [0.14258206491839354]
# recall_score_weighted                               [0.9010622154779969]
# accuracy                                            [0.9010622154779969]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_23  \
# average_precision_score_micro                       [0.9778639049180311]
# AUC_weighted                                        [0.9349519400867283]
# matthews_correlation                               [0.48083688752793513]
# precision_score_micro                               [0.9047040971168437]
# f1_score_micro                                      [0.9047040971168437]
# log_loss                                           [0.19097823746991058]
# weighted_accuracy                                   [0.9508119274235061]
# recall_score_micro                                  [0.9047040971168437]
# average_precision_score_macro                       [0.7990985279132379]
# f1_score_macro                                      [0.7384587461348832]
# precision_score_weighted                            [0.8973973014867108]
# balanced_accuracy                                   [0.7189898248948313]
# average_precision_score_weighted                    [0.9485058416618277]
# AUC_macro                                           [0.9349519400867283]
# AUC_micro                                           [0.9767451949313923]
# precision_score_macro                               [0.7639438984420699]
# recall_score_macro                                  [0.7189898248948313]
# f1_score_weighted                                   [0.9002742628691326]
# norm_macro_recall                                  [0.43797964978966264]
# recall_score_weighted                               [0.9047040971168437]
# accuracy                                            [0.9047040971168437]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_33  \
# average_precision_score_micro                       [0.9796196196728733]
# AUC_weighted                                        [0.9414797155490351]
# matthews_correlation                                [0.5259399920445319]
# precision_score_micro                                [0.910773899848255]
# f1_score_micro                                      [0.9107738998482551]
# log_loss                                           [0.18367219735899293]
# weighted_accuracy                                   [0.9513664458519022]
# recall_score_micro                                   [0.910773899848255]
# average_precision_score_macro                       [0.8117229627891797]
# f1_score_macro                                      [0.7620412675018423]
# precision_score_weighted                            [0.9060295587059544]
# balanced_accuracy                                   [0.7472742276978477]
# average_precision_score_weighted                    [0.9520083415807818]
# AUC_macro                                           [0.9414797155490351]
# AUC_micro                                           [0.9786167941954632]
# precision_score_macro                               [0.7796620555719664]
# recall_score_macro                                  [0.7472742276978477]
# f1_score_weighted                                   [0.9080333369489736]
# norm_macro_recall                                  [0.49454845539569536]
# recall_score_weighted                                [0.910773899848255]
# accuracy                                             [0.910773899848255]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_17  ...  \
# average_precision_score_micro                       [0.9758469753343333]  ...
# AUC_weighted                                        [0.9277762958764242]  ...
# matthews_correlation                                [0.4977863386022065]  ...
# precision_score_micro                               [0.9056145675265553]  ...
# f1_score_micro                                      [0.9056145675265553]  ...
# log_loss                                           [0.20247379062785575]  ...
# weighted_accuracy                                   [0.9482933123099987]  ...
# recall_score_micro                                  [0.9056145675265553]  ...
# average_precision_score_macro                       [0.7752016262592408]  ...
# f1_score_macro                                      [0.7479591292120668]  ...
# precision_score_weighted                            [0.9004265040614122]  ...
# balanced_accuracy                                   [0.7337120517479953]  ...
# average_precision_score_weighted                    [0.9423688594684534]  ...
# AUC_macro                                           [0.9277762958764242]  ...
# AUC_micro                                           [0.9746289614328051]  ...
# precision_score_macro                               [0.7650603991596638]  ...
# recall_score_macro                                  [0.7337120517479953]  ...
# f1_score_weighted                                   [0.9026502097071347]  ...
# norm_macro_recall                                   [0.4674241034959905]  ...
# recall_score_weighted                               [0.9056145675265553]  ...
# accuracy                                            [0.9056145675265553]  ...
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_28  \
# average_precision_score_micro                       [0.9749564287016069]
# AUC_weighted                                        [0.9236167840147299]
# matthews_correlation                                [0.4310920319801482]
# precision_score_micro                               [0.9047040971168437]
# f1_score_micro                                      [0.9047040971168437]
# log_loss                                           [0.21188088475278075]
# weighted_accuracy                                   [0.9634534069425984]
# recall_score_micro                                  [0.9047040971168437]
# average_precision_score_macro                       [0.7683611799619812]
# f1_score_macro                                      [0.7041087255938245]
# precision_score_weighted                            [0.8907543910559076]
# balanced_accuracy                                   [0.6680721574816568]
# average_precision_score_weighted                    [0.9403463886353508]
# AUC_macro                                             [0.92361678401473]
# AUC_micro                                           [0.9737310174748607]
# precision_score_macro                               [0.7764293961911204]
# recall_score_macro                                  [0.6680721574816568]
# f1_score_weighted                                   [0.8931696784078165]
# norm_macro_recall                                  [0.33614431496331365]
# recall_score_weighted                               [0.9047040971168437]
# accuracy                                            [0.9047040971168437]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_29  \
# average_precision_score_micro                       [0.9778967669001765]
# AUC_weighted                                        [0.9343878913840402]
# matthews_correlation                                [0.5031580051738184]
# precision_score_micro                                [0.908649468892261]
# f1_score_micro                                       [0.908649468892261]
# log_loss                                            [0.1922247588509614]
# weighted_accuracy                                   [0.9531273839089858]
# recall_score_micro                                   [0.908649468892261]
# average_precision_score_macro                       [0.7984451398645409]
# f1_score_macro                                      [0.7496193654921842]
# precision_score_weighted                            [0.9018458584236247]
# balanced_accuracy                                   [0.7295002102447545]
# average_precision_score_weighted                    [0.9482288661268924]
# AUC_macro                                           [0.9343878913840402]
# AUC_micro                                           [0.9768399722760148]
# precision_score_macro                               [0.7757818586533111]
# recall_score_macro                                  [0.7295002102447545]
# f1_score_weighted                                   [0.9044708408897457]
# norm_macro_recall                                  [0.45900042048950906]
# recall_score_weighted                                [0.908649468892261]
# accuracy                                             [0.908649468892261]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_7  \
# average_precision_score_micro                      [0.9799175214338409]
# AUC_weighted                                       [0.9422234447908389]
# matthews_correlation                               [0.5152407922685548]
# precision_score_micro                              [0.9101669195751139]
# f1_score_micro                                     [0.9101669195751139]
# log_loss                                           [0.1822581527611655]
# weighted_accuracy                                  [0.9530455225942402]
# recall_score_micro                                 [0.9101669195751139]
# average_precision_score_macro                      [0.8130183856042391]
# f1_score_macro                                     [0.7560397252132639]
# precision_score_weighted                           [0.9041230730193003]
# balanced_accuracy                                  [0.7374594097957384]
# average_precision_score_weighted                    [0.952354416901938]
# AUC_macro                                          [0.9422234447908389]
# AUC_micro                                          [0.9789531662679233]
# precision_score_macro                              [0.7794931081546599]
# recall_score_macro                                 [0.7374594097957384]
# f1_score_weighted                                  [0.9065182421980865]
# norm_macro_recall                                 [0.47491881959147686]
# recall_score_weighted                              [0.9101669195751139]
# accuracy                                           [0.9101669195751139]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_9  \
# average_precision_score_micro                      [0.9726607402338695]
# AUC_weighted                                       [0.9098244502609073]
# matthews_correlation                              [0.43913887192659884]
# precision_score_micro                              [0.9083459787556905]
# f1_score_micro                                     [0.9083459787556905]
# log_loss                                          [0.21709496708504772]
# weighted_accuracy                                  [0.9701362565487615]
# recall_score_micro                                 [0.9083459787556905]
# average_precision_score_macro                       [0.778764693607036]
# f1_score_macro                                     [0.7014409944746076]
# precision_score_weighted                           [0.8948809492824611]
# balanced_accuracy                                  [0.6594655522768488]
# average_precision_score_weighted                   [0.9410281881536726]
# AUC_macro                                          [0.9098244502609072]
# AUC_micro                                          [0.9714910852650703]
# precision_score_macro                              [0.8023269698119038]
# recall_score_macro                                 [0.6594655522768488]
# f1_score_weighted                                  [0.8943159652390001]
# norm_macro_recall                                 [0.31893110455369755]
# recall_score_weighted                              [0.9083459787556905]
# accuracy                                           [0.9083459787556905]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_25  \
# average_precision_score_micro                       [0.8445594902839405]
# AUC_weighted                                                       [0.5]
# matthews_correlation                                               [0.0]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# log_loss                                            [0.3506795575742704]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_macro                                      [0.5]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# average_precision_score_weighted                    [0.8011068409624182]
# AUC_macro                                                          [0.5]
# AUC_micro                                           [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
# norm_macro_recall                                                  [0.0]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_1  \
# average_precision_score_micro                      [0.9791945367231853]
# AUC_weighted                                       [0.9392346349984347]
# matthews_correlation                                [0.488678780261868]
# precision_score_micro                              [0.9071320182094081]
# f1_score_micro                                     [0.9071320182094081]
# log_loss                                           [0.1874363495858499]
# weighted_accuracy                                  [0.9537972210153172]
# recall_score_micro                                 [0.9071320182094081]
# average_precision_score_macro                      [0.8065229883244922]
# f1_score_macro                                     [0.7416848907681176]
# precision_score_weighted                           [0.8991976076061607]
# balanced_accuracy                                  [0.7191727470931578]
# average_precision_score_weighted                   [0.9505970434373063]
# AUC_macro                                          [0.9392346349984347]
# AUC_micro                                          [0.9781770788959222]
# precision_score_macro                              [0.7723958081530135]
# recall_score_macro                                 [0.7191727470931578]
# f1_score_weighted                                  [0.9021127651963996]
# norm_macro_recall                                 [0.43834549418631563]
# recall_score_weighted                              [0.9071320182094081]
# accuracy                                           [0.9071320182094081]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_6  \
# average_precision_score_micro                      [0.9791079428340456]
# AUC_weighted                                       [0.9381111685347885]
# matthews_correlation                               [0.5363097804403674]
# precision_score_micro                              [0.9156297420333839]
# f1_score_micro                                     [0.9156297420333839]
# log_loss                                           [0.2135034031358243]
# weighted_accuracy                                  [0.9591009604102815]
# recall_score_micro                                 [0.9156297420333839]
# average_precision_score_macro                      [0.8126331497869783]
# f1_score_macro                                     [0.7653215674298586]
# precision_score_weighted                           [0.9087584101460493]
# balanced_accuracy                                  [0.7405352812926626]
# average_precision_score_weighted                    [0.951760033506097]
# AUC_macro                                          [0.9381111685347885]
# AUC_micro                                          [0.9781566313055372]
# precision_score_macro                              [0.7989459374215813]
# recall_score_macro                                 [0.7405352812926626]
# f1_score_weighted                                  [0.9110697670738533]
# norm_macro_recall                                  [0.4810705625853251]
# recall_score_weighted                              [0.9156297420333839]
# accuracy                                           [0.9156297420333839]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_12  \
# average_precision_score_micro                       [0.9692086554080706]
# AUC_weighted                                        [0.9011821868047799]
# matthews_correlation                                               [0.0]
# precision_score_micro                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# log_loss                                           [0.22442012332509478]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_macro                       [0.7105912195650106]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# average_precision_score_weighted                    [0.9250821593256537]
# AUC_macro                                           [0.9011821868047798]
# AUC_micro                                           [0.9678045320886707]
# precision_score_macro                               [0.4440060698027314]
# recall_score_macro                                                 [0.5]
# f1_score_weighted                                   [0.8353395018439429]
# norm_macro_recall                                                  [0.0]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_31  \
# average_precision_score_micro                       [0.9792469103727843]
# AUC_weighted                                        [0.9406868983248957]
# matthews_correlation                                [0.4937290323447371]
# precision_score_micro                               [0.9110773899848255]
# f1_score_micro                                      [0.9110773899848255]
# log_loss                                           [0.18485719214536023]
# weighted_accuracy                                   [0.9611104717292754]
# recall_score_micro                                  [0.9110773899848255]
# average_precision_score_macro                       [0.8022857542994071]
# f1_score_macro                                      [0.7410400670578374]
# precision_score_weighted                             [0.901311576372359]
# balanced_accuracy                                   [0.7095528918378726]
# average_precision_score_weighted                    [0.9498586901696163]
# AUC_macro                                           [0.9406868983248957]
# AUC_micro                                           [0.9781896974539526]
# precision_score_macro                               [0.7908196055445871]
# recall_score_macro                                  [0.7095528918378726]
# f1_score_weighted                                   [0.9038810538459678]
# norm_macro_recall                                  [0.41910578367574525]
# recall_score_weighted                               [0.9110773899848255]
# accuracy                                            [0.9110773899848255]
#
#                                  8b93428b-bdf7-4daa-8044-5ebd72e5a6ad_5
# average_precision_score_micro                      [0.8262238440057501]
# AUC_weighted                                       [0.8755411255411256]
# matthews_correlation                               [0.4163137649983421]
# precision_score_micro                              [0.7936267071320182]
# f1_score_micro                                     [0.7936267071320182]
# log_loss                                           [0.5562177726842734]
# weighted_accuracy                                  [0.7935820959186961]
# recall_score_micro                                 [0.7936267071320182]
# average_precision_score_macro                      [0.7207617392904457]
# f1_score_macro                                     [0.6675758406595428]
# precision_score_weighted                            [0.896448506106562]
# balanced_accuracy                                  [0.7938063932929145]
# average_precision_score_weighted                   [0.9232979140063482]
# AUC_macro                                          [0.8755411255411256]
# AUC_micro                                          [0.8550386500906095]
# precision_score_macro                              [0.6474756462789969]
# recall_score_macro                                 [0.7938063932929145]
# f1_score_weighted                                   [0.826428509742894]
# norm_macro_recall                                  [0.5876127865858289]
# recall_score_weighted                              [0.7936267071320182]
# accuracy                                           [0.7936267071320182]
#
# [21 rows x 36 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/8b93428b-bdf7-4daa-8044-5ebd72e5a6ad/model_data
# Downloaded azureml/8b93428b-bdf7-4daa-8044-5ebd72e5a6ad/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  reg_lambda=0.2631578947368421,
#                                                                                                                                  silent=True,
#                                                                                                                                  subsample=1,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.2857142857142857,
#                                                                                          0.2857142857142857,
#                                                                                          0.07142857142857142,
#                                                                                          0.14285714285714285,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('6',
#                                              Pipeline(memory=None,
#                                                       steps=[('truncatedsvdwrapper',
#                                                               TruncatedSVDWrapper(n_components=0.8510526315789474,
#                                                                                   random_state=None)),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=0.7,
#                                                                                 eta=0.2,
#                                                                                 gamma=0.01,
#                                                                                 lea...
#                                                                                  objective=None,
#                                                                                  random_state=None,
#                                                                                  reg_alpha=0.42105263157894735,
#                                                                                  reg_lambda=0.2631578947368421,
#                                                                                  silent=True,
#                                                                                  subsample=1,
#                                                                                  subsample_for_bin=200000,
#                                                                                  subsample_freq=0,
#                                                                                  verbose=-10))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.2857142857142857, 0.2857142857142857,
#                                          0.07142857142857142, 0.14285714285714285,
#                                          0.07142857142857142, 0.07142857142857142,
#                                          0.07142857142857142]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://raw.githubusercontent.com/webpagearshi/Operationalizing-ML/master/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_43e696c2_41ee_11eb_918e_000d3aecd583row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_43e696c2_41ee_11eb_918e_000d3aecd583row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_43e696c2_41ee_11eb_918e_000d3aecd583row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_43e696c2_41ee_11eb_918e_000d3aecd583row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_43e696c2_41ee_11eb_918e_000d3aecd583" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43e696c2_41ee_11eb_918e_000d3aecd583level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_43e696c2_41ee_11eb_918e_000d3aecd583row0_col0" class="data row0 col0" >28527</td>
#                         <td id="T_43e696c2_41ee_11eb_918e_000d3aecd583row0_col1" class="data row0 col1" >731</td>
#             </tr>
#             <tr>
#                         <th id="T_43e696c2_41ee_11eb_918e_000d3aecd583level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_43e696c2_41ee_11eb_918e_000d3aecd583row1_col0" class="data row1 col0" >1335</td>
#                         <td id="T_43e696c2_41ee_11eb_918e_000d3aecd583row1_col1" class="data row1 col1" >2357</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 8ed492e8-d67f-4bd1-b7c0-496c371dfb84,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/1b944a9b-fdae-4f97-aeb1-b7eea0beac53/resourceGroups/aml-quickstarts-130975/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-130975/PipelineRuns/PipelineSubmit/8ed492e8-d67f-4bd1-b7c0-496c371dfb84)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  71569262-c00d-4635-8c47-68479e16055b

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
#from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
#RunDetails(published_pipeline_run).show()
